# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier
# Out:
# /tmp/ipykernel_16271/3016242139.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df=pd.read_csv("titanic dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(columns= ['PassengerId','Name','Ticket','Cabin'],inplace=True)

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  34.5      0      0   7.8292        Q
# 1         1       3  female  47.0      1      0   7.0000        S
# 2         0       2    male  62.0      0      0   9.6875        Q
# 3         0       3    male  27.0      0      0   8.6625        S
# 4         1       3  female  22.0      1      1  12.2875        S

# %%
df.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Embarked     0
# dtype: int64

# %%
x_train,x_test,y_train,y-test = train_test_split(df.drop(columns = ['Survived'],df['urvived']))

# %%
from sklearn.compose import ColumnTransformer
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2 
from sklearn.pipeline import Pipeline, make_pipeline

# %% [markdown]
# using ColumnTransformer to fill missing val by Imputer.SimpleImputer() fills empty cols with mean value. If we want to fill it with most frequent value then we have to use SimpleImputer(strategy = "most_frequent")
# If you want to fill missing values with the least frequent value in each column using SimpleImputer, you should use strategy="constant" along with the fill_value parameter set to the least frequent value.
# SimpleImputer(strategy='constant', fill_value=np.nan)

# %%
tf1 = ColumnTransformer([('age_imputer',SimpleImputer(),[3]),
                         ('fare_imputer',SimpleImputer(),[6])],remainder = 'passthrough')

# %%
tf1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('age_imputer', SimpleImputer(), [3]),
#                                 ('fare_imputer', SimpleImputer(), [6])])

# %% [markdown]
# Now we will create transformer for one hot encoder

# %%
tf2 = ColumnTransformer([('sex_embarked_ohe',
                          OneHotEncoder(sparse_output=False, handle_unknown='ignore'),[2,7])],remainder='passthrough')

# %%
tf2
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('sex_embarked_ohe',
#                                  OneHotEncoder(handle_unknown='ignore',
#                                                sparse_output=False),
#                                  [2, 7])])

# %% [markdown]
# Creating transformer for Scaling purpose. Scaling should be done inorder to select features

# %%
tf3 = ColumnTransformer(['scaling',MinMaxScaler(),slice(0,8)])
tf3
# Out:
# ColumnTransformer(transformers=['scaling', MinMaxScaler(), slice(0, 8, None)])

# %%
tf4= SelectKBest(score_func = chi2, k=5)

# %%
tf4
# Out:
# SelectKBest(k=5, score_func=<function chi2 at 0x7f59e3070e50>)

# %%
tf5 = DecisionTreeClassifier()

# %%
Now we will create a pipeline that  will wrap up all the above  predefined transformer
the difference between Pipeline and make_pipeline is clearly visible in pipe1 and pipe2
# Out:
#   File "/tmp/ipykernel_16271/1244489166.py", line 1
#     Now we will create a pipeline that  will wrap up all the above  predefined transformer
#         ^
# SyntaxError: invalid syntax

# %%
pipe1 = Pipeline([('tf1',tf1),
                 ('tf2',tf2),
                 ('tf3',tf3),
                 ('tf4',tf4),
                 ('tf5',tf5)
                  ])

# %%
pipe2 = make_pipeline(tf1,tf2,tf3,tf4,tf5)

# %%
pipe1.fit(x_train,y-train)
