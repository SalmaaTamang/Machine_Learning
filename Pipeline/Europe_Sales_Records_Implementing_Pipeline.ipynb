# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("Europe Sales Records.csv")
df.head()
# Out:
#    Region                 Country        Item Type Sales Channel  \
# 0  Europe          Czech Republic        Beverages       Offline
# 1  Europe  Bosnia and Herzegovina          Clothes        Online
# 2  Europe                 Austria           Cereal       Offline
# 3  Europe                Bulgaria  Office Supplies        Online
# 4  Europe                 Estonia           Fruits        Online
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              C   9/12/2011  478051030   9/29/2011        4778       47.45
# 1              M  10/14/2013  919133651   11/4/2013         927      109.28
# 2              C   8/13/2014  987410676    9/6/2014        5616      205.70
# 3              L  10/31/2010  672330081  11/29/2010        6266      651.21
# 4              L   9/28/2016  579463422   11/1/2016        4958        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      31.79      226716.10   151892.62      74823.48
# 1      35.84      101302.56    33223.68      68078.88
# 2     117.11     1155211.20   657689.76     497521.44
# 3     524.96     4080481.86  3289399.36     791082.50
# 4       6.92       46258.14    34309.36      11948.78

# %%
df.shape
# Out:
# (1330, 14)

# %%
df.columns
# Out:
# Index(['Region', 'Country', 'Item Type', 'Sales Channel', 'Order Priority',
#        'Order Date', 'Order ID', 'Ship Date', 'Units Sold', 'Unit Price',
#        'Unit Cost', 'Total Revenue', 'Total Cost', 'Total Profit'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Region            0
# Country           0
# Item Type         0
# Sales Channel     0
# Order Priority    0
# Order Date        0
# Order ID          0
# Ship Date         0
# Units Sold        0
# Unit Price        0
# Unit Cost         0
# Total Revenue     0
# Total Cost        0
# Total Profit      0
# dtype: int64

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
df["Ship Date"] = pd.to_datetime(df["Ship Date"])
df.head()
# Out:
#    Region                 Country        Item Type Sales Channel  \
# 0  Europe          Czech Republic        Beverages       Offline
# 1  Europe  Bosnia and Herzegovina          Clothes        Online
# 2  Europe                 Austria           Cereal       Offline
# 3  Europe                Bulgaria  Office Supplies        Online
# 4  Europe                 Estonia           Fruits        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              C 2011-09-12  478051030 2011-09-29        4778       47.45
# 1              M 2013-10-14  919133651 2013-11-04         927      109.28
# 2              C 2014-08-13  987410676 2014-09-06        5616      205.70
# 3              L 2010-10-31  672330081 2010-11-29        6266      651.21
# 4              L 2016-09-28  579463422 2016-11-01        4958        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit
# 0      31.79      226716.10   151892.62      74823.48
# 1      35.84      101302.56    33223.68      68078.88
# 2     117.11     1155211.20   657689.76     497521.44
# 3     524.96     4080481.86  3289399.36     791082.50
# 4       6.92       46258.14    34309.36      11948.78

# %%
df["Ordered Days"] = (df["Ship Date"]-df["Order Date"]).dt.days
df.head()
# Out:
#    Region                 Country        Item Type Sales Channel  \
# 0  Europe          Czech Republic        Beverages       Offline
# 1  Europe  Bosnia and Herzegovina          Clothes        Online
# 2  Europe                 Austria           Cereal       Offline
# 3  Europe                Bulgaria  Office Supplies        Online
# 4  Europe                 Estonia           Fruits        Online
#
#   Order Priority Order Date   Order ID  Ship Date  Units Sold  Unit Price  \
# 0              C 2011-09-12  478051030 2011-09-29        4778       47.45
# 1              M 2013-10-14  919133651 2013-11-04         927      109.28
# 2              C 2014-08-13  987410676 2014-09-06        5616      205.70
# 3              L 2010-10-31  672330081 2010-11-29        6266      651.21
# 4              L 2016-09-28  579463422 2016-11-01        4958        9.33
#
#    Unit Cost  Total Revenue  Total Cost  Total Profit  Ordered Days
# 0      31.79      226716.10   151892.62      74823.48            17
# 1      35.84      101302.56    33223.68      68078.88            21
# 2     117.11     1155211.20   657689.76     497521.44            24
# 3     524.96     4080481.86  3289399.36     791082.50            29
# 4       6.92       46258.14    34309.36      11948.78            34

# %%
df.loc[df['Total Profit'] >100000,'Result'] =1
df.loc[df['Total Profit'] <100000,'Result'] =0
df.tail()
# Out:
#       Region  Country      Item Type Sales Channel Order Priority Order Date  \
# 1325  Europe   Norway  Personal Care       Offline              M 2014-01-14
# 1326  Europe  Ukraine         Cereal       Offline              L 2014-04-14
# 1327  Europe  Armenia           Meat       Offline              M 2015-11-09
# 1328  Europe  Denmark        Clothes       Offline              H 2012-05-09
# 1329  Europe  Finland        Clothes        Online              L 2014-04-22
#
#        Order ID  Ship Date  Units Sold  Unit Price  Unit Cost  Total Revenue  \
# 1325  634033286 2014-01-15        3394       81.73      56.67      277391.62
# 1326  559183347 2014-05-21        3633      205.70     117.11      747308.10
# 1327  781416594 2015-12-23        7390      421.89     364.69     3117767.10
# 1328  713357150 2012-06-03        7088      109.28      35.84      774576.64
# 1329  906794202 2014-05-11        9410      109.28      35.84     1028324.80
#
#       Total Cost  Total Profit  Ordered Days  Result
# 1325   192337.98      85053.64             1     0.0
# 1326   425460.63     321847.47            37     1.0
# 1327  2695059.10     422708.00            44     1.0
# 1328   254033.92     520542.72            25     1.0
# 1329   337254.40     691070.40            19     1.0

# %%
df['Region'].unique()
# Out:
# array(['Europe'], dtype=object)

# %%
len(df['Country'].unique())
# Out:
# 48

# %%
len(df['Item Type'].unique())
# Out:
# 12

# %%
df_train = df.drop(columns = ['Region', 'Order Date', 'Order ID', 'Ship Date','Result','Ordered Days'],axis=1)
df_test = df['Result']

# %%
x_train,x_test,y_train,y_test = train_test_split(df_train,df_test, test_size = 0.2, random_state=42)

# %%
x_train.head()
# Out:
#             Country        Item Type Sales Channel Order Priority  Units Sold  \
# 844          Latvia  Office Supplies        Online              L        4375
# 170        Slovenia        Household        Online              C        6992
# 942         Estonia        Beverages       Offline              L        8222
# 461  United Kingdom    Personal Care       Offline              L        4509
# 209     Netherlands        Baby Food       Offline              C        4077
#
#      Unit Price  Unit Cost  Total Revenue  Total Cost  Total Profit
# 844      651.21     524.96     2849043.75  2296700.00     552343.75
# 170      668.27     502.54     4672543.84  3513759.68    1158784.16
# 942       47.45      31.79      390133.90   261377.38     128756.52
# 461       81.73      56.67      368520.57   255525.03     112995.54
# 209      255.28     159.42     1040776.56   649955.34     390821.22

# %%
from sklearn import set_config
set_config(display='diagram')

# %%
ohe = OneHotEncoder()
ohe_cols=[0,1,2,3]
trf1 = ColumnTransformer([('ohe_cat',ohe,ohe_cols)],remainder = 'passthrough')

# %%
trf1
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ohe_cat', OneHotEncoder(), [0, 1, 2, 3])])

# %%
trf2 = DecisionTreeClassifier()

# %%
pipe = Pipeline([('trf1',trf1),('trf2',trf2)])
pipe
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_cat', OneHotEncoder(),
#                                                   [0, 1, 2, 3])])),
#                 ('trf2', DecisionTreeClassifier())])

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('trf1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe_cat', OneHotEncoder(),
#                                                   [0, 1, 2, 3])])),
#                 ('trf2', DecisionTreeClassifier())])

# %%
 predicated=pipe.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(predicated,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(predicated,y_test)
cm
# Out:
# array([[ 76,   0],
#        [  0, 190]])
